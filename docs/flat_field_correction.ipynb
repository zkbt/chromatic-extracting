# %% [markdown]
# # Flat Field Correction
# This tutorial will walk through the steps for flat field correction.

# %%
from main_zasha_v02 import *
import matplotlib

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# Save the folder directory containing the flat field files:

# %%
flat_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Flat/c1'

# %% [markdown]
# ## Interactive Figure

# %% [markdown]
# Now an interactive figure can be plotted to visualize the flat files. Start by sorted the list by date-time and then display the figure:

# %%
sorted_list = sorted_datetime(flat_directory)

# %%
# %matplotlib notebook
animation(sorted_list, 'object', 'exptime', 'airmass')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Median Flat Field Image

# %%
median_flat = median_image(flat_directory, 'Flat')
# Out:
# <img src="data:image/png;base64,..." width="800">
