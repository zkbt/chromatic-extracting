# %% [markdown]
# # main_zasha_v04.py Functions

# %% [markdown]
# ### Imports

# %%
from main_zasha_v04 import *
import matplotlib

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ### Source Folders

# %%
# Directory containing FITS files
fits_directory = '/Users/zashaavery/Documents/WASP-94A_fits/ut140801'
bias_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c2/grism/VPH-All/c2'
flat_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Wide Flat/c2'
object_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/WASP-94/c2'
VPH_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/VPH-All/c2'

# %% [markdown]
# ### def organize_files(source_folder, destination_folder, header_keyword, file_type=None)
# -will organize files into a new folder depending on an inputted header

# %%
# Define the source folder containing the FITS files and the destination parent folder.
source_folder = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c2'
destination_folder = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c2/grism'

# Organize 'c1' and 'c2' files based on 'exptype'. 'exptype' contains OBJECT, BIAS, FLAT, etc
organize_files(source_folder, destination_folder, 'grism', 'c2')

# %% [markdown]
# ### def headers(image_directory)
# -prints out a list of available headers fro the fits files in alphabetical order

# %%
headers(object_directory)
# Out:
# ['AIRMASS', 'APERTURE', 'ASECS', 'BIASSEC', 'BINNING', 'BITPIX', 'BSCALE', 'BUNIT', 'BZERO', 'CCDSETP', 'CHOFFX', 'CHOFFY', 'COMMENT', 'DATASEC', 'DATE-OBS', 'DEC', 'DEC-D', 'DEWARORI', 'DISPAXIS', 'DSECS', 'DWELTIME', 'EGAIN', 'ENOISE', 'EPOCH', 'EQUINOX', 'EXPTIME', 'EXPTYPE', 'FILENAME', 'FILTER', 'FITSVERS', 'FOCUS', 'GAIN', 'GRISM', 'HA', 'HEATER', 'INSTRUME', 'LC-TIME', 'LOOP', 'NAXIS', 'NAXIS1', 'NAXIS2', 'NBIASLNS', 'NCYCLES', 'NIGHT', 'NLOOPS', 'NOD-DEC', 'NOD-RA', 'NOPAMPS', 'NOVERSCN', 'NSHUFFLE', 'OBJECT', 'OBSERVER', 'OPAMP', 'ORIGIN', 'RA', 'RA-D', 'ROTANGLE', 'ROTATORE', 'SCALE', 'SIMPLE', 'SITEALT', 'SITELAT', 'SITELONG', 'SITENAME', 'SOFTWARE', 'SPEED', 'ST', 'SUBRASTR', 'TEL-ELEV', 'TELESCOP', 'TEMPCCD', 'TEMPLDSS', 'TEMPNECK', 'TEMPSL1', 'TEMPSL3', 'TEMPSL5', 'TEMPSTGE', 'TIME-OBS', 'TIMEZONE', 'UT-DATE', 'UT-END', 'UT-TIME']

# %% [markdown]
# ### def headers_data(image_directory, header)
# -allows the user to get the corresponding data to a header

# %%
header = 'grism' ##can change the header to any of the headers above to get the data associated with that header 
headers_data(object_directory, header)
# Out:
# array(['VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'Open',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'Open', 'VPH-All',
#        'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All', 'VPH-All',
# ...

# %% [markdown]
# ### def sorted_datetime(image_directory)
# -sorts the files in a directory in terms of observation date-time

# %%
sorted_list = sorted_datetime(VPH_directory)
#for filename, obs_datetime, header_data, image_data in sorted_list:
    #print(f"Filename: {filename}, Observation Datetime: {obs_datetime}") 
##can print to see the sorted file names, observation datetime, header data, and image data

# %% [markdown]
# ### def interactive(sorted_list, *header_names, vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -plots an interactive figure with three total plots/images (the original image, a time-series plot of pixels, histogram of pixels with gaussian distribution)

# %%
# %matplotlib notebook
interactive(sorted_list, 'object', 'exptime', 'airmass') ##creates a sliding animation that allows you to look
# at fits images in order. Can add additional headers as shown that will appear to the right of the figure
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ### def median_image(image_directory, median_name,  vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -will display an image representing the median to a set of FITS images

# %%
median_image(flat_directory, 'Flat')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### median_image_data(image_directory)
# -returns the median, unnormalized image data from median_image()

# %%
median_data = median_image_data(flat_directory)

# %% [markdown]
# ### def read_noise(image_directory)
# -returns the read noise from the bias image

# %%
read_noise = read_noise(bias_directory)

# %% [markdown]
# ### def median_filter(median_data,  vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -applies a median filter to the median, unnormalized image

# %%
median_filter(median_data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### def median_filter_data(median_data)
# -returns the data from median_filter()

# %%
filter_data = median_filter_data(median_data)

# %% [markdown]
# ### def normalized_image(median_data, filter_data,  vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -plots the normalized, median image

# %%
normalized_image(median_data, filter_data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### def normalized_image_data(median_data, filter_data)
# -returns the data for normalized_image()

# %%
normal_data = normalized_image_data(median_data, filter_data)

# %% [markdown]
# ### def corrected_image(sorted_list, B, F, g, vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -plots an interactive figure of the corrected images

# %%
B = median_image_data(bias_directory)
median_data = median_image_data(flat_directory)
median_filter = median_filter_data(median_data)
F = normalized_image_data(median_data, median_filter)
g = headers_data(VPH_directory, 'egain')

corrected_image(sorted_list, B, F, g)
# Out:
# <img src="data:image/png;base64,..." width="700">
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:680: RuntimeWarning: divide by zero encountered in divide
#   S = (P - B) / (g * F)
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:680: RuntimeWarning: invalid value encountered in divide
#   S = (P - B) / (g * F)

# %% [markdown]
# ### def corrected_image_data(image_list, B, F, g)
# -returns the data for corrected_image()

# %%
corrected_data = corrected_image_data(sorted_list, B, F, g)
# Out:
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:732: RuntimeWarning: divide by zero encountered in divide
#   S = (P - B) / (g * F)
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:732: RuntimeWarning: invalid value encountered in divide
#   S = (P - B) / (g * F)

# %% [markdown]
# ### def save_corrected_image(image_list, B, F, g, destination_folder):
# -saves the image data for the set of corrected images in a defined folder

# %%
corrected_directory = '/Users/zashaavery/Documents/WASP-94A_fits/corrected_images'
save_corrected_image(sorted_list, B, F, g, corrected_directory)
# Out:
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:765: RuntimeWarning: divide by zero encountered in divide
#   S = (P - B) / (g * F)
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:765: RuntimeWarning: invalid value encountered in divide
#   S = (P - B) / (g * F)

# %% [markdown]
# ### def show_corrected_image(image_filename, vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(8,6)):
# -allows the user to view a single corrected image

# %%
corrected_filename = "/Users/zashaavery/Documents/WASP-94A_fits/corrected_images/corrected_ccd0356c2.fits"
show_corrected_image(corrected_filename)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### def measured_noise_image(image_list, image_number=10, vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', fontsize=8, figsize=(7,8), current_frame=0, norm='linear')
# -displays the image representing the measured noise (the standard deviation per pixel for all images in a set list)

# %%
measured_noise_image(sorted_list)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### def measured_noise_data(image_list, image_number=10):
# -saves the data for measured_noise_image()

# %%
measured_noise_data = measured_noise_data(sorted_list)

# %% [markdown]
# ### def save_measured_noise(image_list, destination_folder, image_number = 10):
# -saves the image from measured_noise() to a destination folder

# %%
noise_directory = '/Users/zashaavery/Documents/WASP-94A_fits/measured_noise_image'
save_measured_noise(sorted_list, noise_directory)

# %% [markdown]
# ### def uncertainty_image(N, read_noise, N_fraction=1, vmin_initial=1000, vmax_initial=3000, valstep=1, cmap='gray', figsize=(8,6), norm='linear'):
# -plots the uncertainty image based off of read noise and photon noise

# %%
uncertainty_image(corrected_directory, read_noise)
# Out:
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:983: RuntimeWarning: invalid value encountered in sqrt
#   total_uncertainty = np.sqrt(read_noise**2 + image_data)
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### def save_uncertainty_images(folder_path, read_noise_destination_folder):
# -saves the images from uncertainty_image

# %%
uncertainty_directory = '/Users/zashaavery/Documents/WASP-94A_fits/uncertainty_images'
save_uncertainty_images(corrected_directory, read_noise, uncertainty_directory)
# Out:
# /Users/zashaavery/Documents/chromatic_extracting_zasha/main_zasha_v04.py:1040: RuntimeWarning: invalid value encountered in sqrt
#   total_uncertainty = np.sqrt(read_noise**2 + image_data)
