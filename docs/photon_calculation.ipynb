# %% [markdown]
# # Photon Calculation
# This tutorial will use bias and flat exposures to find the photons per pixel. The following equation is used to solve for the photons, S:
#
# P_i,j = SgF + B
#
# where P_i,j is the pixels of the original image, S is the photons, g is the gain, F is the flat image pixels, and B is the bias image pixels.

# %%
from main_zasha_v02 import *
import matplotlib

import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
bias_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c1'
flat_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Flat/c1'
object_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/WASP-94/c1'

# %%
B = median_image_data(bias_directory)

# %%
median_data = median_image_data(flat_directory)
median_filter = median_filter_data(median_data)
F = normalized_data(median_data, median_filter)

# %% [markdown]
# Work for P:

# %%
g = headers_data(object_directory, 'egain')

# %% [markdown]
# ## Solve for S

# %%
# %matplotlib notebook
#%matplotlib qt
corrected_image(object_directory, B, F, g)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Photon Noise

# %%
sorted_list = sorted_datetime(object_directory)

# %%
animation(sorted_list, 'object', 'exptime', 'airmass')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
photon_noise = noise(sorted_list, image_fraction = 0.2)
