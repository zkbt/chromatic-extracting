# %% [markdown]
# # Bias Reduction
# This tutorial will walk through steps to work with bias images.

# %%
from main_zasha import *
import matplotlib

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# First, a folder needs to be created that contains the organized bias images:

# %%
# Define the source folder containing the FITS files and the destination parent folder.
source_folder = '/Users/zashaavery/Documents/WASP-94A_fits/ut140801 copy'
destination_parent_folder = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files'

# Organize 'c1' and 'c2' files based on 'exptype'. 'exptype' contains OBJECT, BIAS, FLAT, etc
organize_files(source_folder, destination_parent_folder, 'exptype', 'c1')

# %% [markdown]
# Save the folder directory containing the bias files:

# %%
bias_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c1'

# %% [markdown]
# Create a variable to run functions in main_zasha.py under class FileManager:

# %%
manager = FileManager(bias_directory)

# %% [markdown]
# ## Interactive Figure

# %% [markdown]
# Now an interactive figure can be plotted to visualize the bias files. Start by sorted the list by date-time and then display the figure:

# %%
sorted_list = manager.sorted_datetime()

# %%
# %matplotlib notebook
manager.animation(sorted_list, 'object', 'exptime', 'airmass')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Median Bias Calibration Image

# %% [markdown]
# A median bias calibration image can be created using the median_image() function.

# %%
median_image(bias_directory, 'Bias')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
read_noise(bias_directory)
# Out:
# array([14.72588059, 11.8370692 , 10.2996394 ,  9.50759986,  9.0646038 ,
#         8.86313721,  8.70980517,  8.60422675,  8.56757534,  8.53635937,
#         8.46814523,  8.46152221,  8.44781585,  8.43721193,  8.40059934,
#         8.407658  ,  8.41171806,  8.4259323 ,  8.44200543,  8.42370495,
#         8.42387263,  8.43187203,  8.39924797,  8.42515672,  8.425259  ,
#         8.41934621,  8.41539013,  8.39063361,  8.3667198 ,  8.36769264,
#         8.36861134,  8.38135917,  8.37551966,  8.36625341,  8.36777274,
#         8.40609251,  8.38130133,  8.35504367,  8.36451072,  8.39025845,
#         8.35512198,  8.36407558,  8.40081663,  8.36492105,  8.32873537,
#         8.34339158,  8.33591944,  8.2995808 ,  8.34022555,  8.33614644,
#         8.34981753,  8.35770429,  8.36132613,  8.35607573,  8.31856189,
#         8.31840484,  8.32686175,  8.31729136,  8.28620817,  8.30670436,
#         8.32972738,  8.31258943,  8.32259314,  8.26093849,  8.28514038,
# ...
