# %% [markdown]
# # Bias Reduction
# This tutorial will walk through steps to work with bias images.

# %%
from main_zasha_v02 import *
import matplotlib
matplotlib.interactive(True)

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# Save the folder directory containing image files:

# %%
bias_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Bias/c1'
flat_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/Flat/c1'
object_directory = '/Users/zashaavery/Documents/WASP-94A_fits/organized_files/WASP-94/c1'

# %% [markdown]
# ## Interactive Figure

# %% [markdown]
# Now an interactive figure can be plotted to visualize the bias files. Start by sorting the list by date-time and then display the figure:

# %%
bias_list = sorted_datetime(bias_directory)

# %%
# %matplotlib notebook
##%matplotlib qt pulls up window with plot
animation(bias_list, 'object', 'exptime', 'airmass')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Median Bias Calibration Image

# %% [markdown]
# A median bias calibration image can be created using the median_image() function.

# %%
median_image(bias_directory, 'Bias')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Uncertainty Image

# %%
read_noise = read_noise(bias_directory)

# %%
object_list = sorted_datetime(object_directory)
photon_noise = noise(object_list, image_fraction = 0.2)

# %%
uncertainty_image(read_noise, photon_noise)
# Out:
# <img src="data:image/png;base64,..." width="800">
